# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import the file

# %%
path = 'C:\\Users\\User\\Desktop\\DATA SCIENCE\\Abhinav R\\datasets\\Attrition Case Study.csv'
data = pd.read_csv(path)

# %% [markdown]
# #  Explore the data

# %%
data.head()
# Out:
#    Attrition  Age     BusinessTravel  DailyRate              Department  \
# 0          1   41      Travel_Rarely       1102                   Sales
# 1          0   49  Travel_Frequently        279  Research & Development
# 2          1   37      Travel_Rarely       1373  Research & Development
# 3          0   33  Travel_Frequently       1392  Research & Development
# 4          0   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.dtypes
# Out:
# Attrition                    int64
# Age                          int64
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# # Convert categorical predictors to type 'category'

# %%
data['OverTime'] = data['OverTime'].astype('category')
data['Over18'] = data['Over18'].astype('category')
data['MaritalStatus'] = data['MaritalStatus'].astype('category')
data['JobRole'] = data['JobRole'].astype('category')
data['Gender'] = data['Gender'].astype('category')
data['EducationField'] = data['EducationField'].astype('category')
data['Department'] = data['Department'].astype('category')
data['BusinessTravel'] = data['BusinessTravel'].astype('category')
data['Attrition'] = data['Attrition'].astype('category')
data['Education'] = data['Education'].astype('category')
data['EnvironmentSatisfaction'] = data['EnvironmentSatisfaction'].astype('category')
data['JobInvolvement'] = data['JobInvolvement'].astype('category')
data['JobLevel'] = data['JobLevel'].astype('category')
data['JobSatisfaction'] = data['JobSatisfaction'].astype('category')
data['PerformanceRating'] = data['PerformanceRating'].astype('category')
data['RelationshipSatisfaction'] = data['RelationshipSatisfaction'].astype('category')
data['StockOptionLevel'] = data['StockOptionLevel'].astype('category')
data['WorkLifeBalance'] = data['WorkLifeBalance'].astype('category')

# %%
data.dtypes
# Out:
# Attrition                   category
# Age                            int64
# BusinessTravel              category
# DailyRate                      int64
# Department                  category
# DistanceFromHome               int64
# Education                   category
# EducationField              category
# EmployeeCount                  int64
# EmployeeNumber                 int64
# EnvironmentSatisfaction     category
# Gender                      category
# HourlyRate                     int64
# JobInvolvement              category
# JobLevel                    category
# JobRole                     category
# JobSatisfaction             category
# MaritalStatus               category
# MonthlyIncome                  int64
# MonthlyRate                    int64
# NumCompaniesWorked             int64
# Over18                      category
# OverTime                    category
# PercentSalaryHike              int64
# PerformanceRating           category
# ...

# %%
data_columns = list()
data_columns = data.columns

for i in range(len(data_columns)):
    
    if data[data_columns[i]]. dtype == 'int64':
        print("="*50)
        print(data_columns[i])
        print("="*50,'\n')
        
        
        
    
    else:
        
        print(data_columns[i])
        print("-"*50)
        print(data[data_columns[i]].value_counts())
        print("-"*50,'\n')
# Out:
# Attrition
# --------------------------------------------------
# 0    1233
# 1     237
# Name: Attrition, dtype: int64
# --------------------------------------------------
#
# ...
# Age
# ...
#
# BusinessTravel
# --------------------------------------------------
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# --------------------------------------------------
#
# ...
# DailyRate
# ...
#
# Department
# --------------------------------------------------
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# --------------------------------------------------
#
# ...
# DistanceFromHome
# ...
#
# Education
# --------------------------------------------------
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64
# --------------------------------------------------
#
# EducationField
# --------------------------------------------------
# ...

# %%
len(data.index)
# Out:
# 1470

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Quantitative data
#  * Box plot
#  * Histogram
#  * Strip plot
#  * Violin Plot
#  * Distribution with Histogram

# %% [markdown]
#  Categorical
#
#  * Bar graph
#  * Count plot
#  * Pie chart

# %%
data_columns = list()
data_columns = data.columns

for i in range(len(data_columns)):
    
    if data[data_columns[i]]. dtype == 'int64':
        plt.figure(1)
        plt.figure(figsize=(12,8))
        plt.subplot(2,2,1)
        sns.boxplot(x=data[data_columns[i]], data= data)
        plt.subplot(2,2,2)
        plt.hist(data[data_columns[i]]);
        plt.xlabel(data_columns[i])
        plt.tight_layout() 
        plt.show()
         
    else:
        
        plt.figure()
        sns.countplot(x=data[data_columns[i]], data = data)

# %% [markdown]
# # Distribution of all quantitative predictors

# %%
fig,ax = plt.subplots(4,4, figsize=(18,18))              
sns.distplot(data['TotalWorkingYears'], ax = ax[0,0]) 
sns.distplot(data['YearsAtCompany'], ax = ax[0,1]) 
sns.distplot(data['DistanceFromHome'], ax = ax[0,2]) 
sns.distplot(data['NumCompaniesWorked'], ax = ax[0,3])
sns.distplot(data['YearsInCurrentRole'], ax = ax[1,0]) 
sns.distplot(data['YearsWithCurrManager'], ax = ax[1,1]) 
sns.distplot(data['YearsSinceLastPromotion'], ax = ax[1,2])
sns.distplot(data['HourlyRate'], ax = ax[1,3])
sns.distplot(data['PercentSalaryHike'], ax = ax[2,0]) 
sns.distplot(data['YearsSinceLastPromotion'], ax = ax[2,1]) 
sns.distplot(data['TrainingTimesLastYear'], ax = ax[2,2]) 
sns.distplot(data['MonthlyRate'], ax = ax[2,3])
sns.distplot(data['MonthlyIncome'], ax = ax[3,0])
sns.distplot(data['StandardHours'], ax = ax[3,1])
sns.distplot(data['Age'], ax = ax[3,2])
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# Quantitative --> Quantitative
#
# *  Scatter plot

# %% [markdown]
# Categorical --> Quantitative
#
# * Side by side box plot

# %%
data_columns = list()
data_columns = data.columns

for i in range(len(data_columns)):
    
    if data[data_columns[i]]. dtype == 'int64':
        
        plt.figure()
        plt.scatter(data[data_columns[i]],data['MonthlyIncome'])
        plt.xlabel(data_columns[i])
        
        
        #print("***********************\n")
    
    else:
       
        plt.figure()
        sns.boxplot(data[data_columns[i]],data['MonthlyIncome'])

# %% [markdown]
# # Test of hypothesis

# %% [markdown]
# Y = MonthlyIncome is quantitative thus we do C --> Q and Q --> Q test of hypothesis
#
#  C-->Q
#
#    * t test for independent samples
#    * f test(annova) for more than two independent samples
#
# Q-->Q
#
#    * t test for population slope

# %%
from sklearn.linear_model import LinearRegression
from statsmodels.iolib.summary import Summary
import statsmodels.api as sm
from scipy import stats

# %% [markdown]
# # Q-->Q   t test for population slope

# %%
help(sm.OLS)
# Out:
# Help on class OLS in module statsmodels.regression.linear_model:
#
# class OLS(WLS)
#  |  OLS(endog, exog=None, missing='none', hasconst=None, **kwargs)
#  |
#  |  A simple ordinary least squares model.
#  |
#  |
#  |  Parameters
#  |  ----------
#  |  endog : array-like
#  |      1-d endogenous response variable. The dependent variable.
#  |  exog : array-like
#  |      A nobs x k array where `nobs` is the number of observations and `k`
#  |      is the number of regressors. An intercept is not included by default
#  |      and should be added by the user. See
#  |      :func:`statsmodels.tools.add_constant`.
#  |  missing : str
#  |      Available options are 'none', 'drop', and 'raise'. If 'none', no nan
#  |      checking is done. If 'drop', any observations with nans are dropped.
#  |      If 'raise', an error is raised. Default is 'none.'
#  |  hasconst : None or bool
#  |      Indicates whether the RHS includes a user-supplied constant. If True,
# ...

# %%
X = data['Age']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.248
# Model:                            OLS   Adj. R-squared:                  0.247
# Method:                 Least Squares   F-statistic:                     483.8
# Date:                Sun, 03 May 2020   Prob (F-statistic):           6.67e-93
# Time:                        23:16:40   Log-Likelihood:                -14308.
# No. Observations:                1470   AIC:                         2.862e+04
# Df Residuals:                    1468   BIC:                         2.863e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
X = data['DailyRate']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.08720
# Date:                Sun, 03 May 2020   Prob (F-statistic):              0.768
# Time:                        23:16:41   Log-Likelihood:                -14517.
# No. Observations:                1470   AIC:                         2.904e+04
# Df Residuals:                    1468   BIC:                         2.905e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6430.7699    273.500     23.513      0.000    5894.278    6967.262
# ...

# %%
X = data['DistanceFromHome']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.4251
# Date:                Sun, 03 May 2020   Prob (F-statistic):              0.515
# Time:                        23:16:41   Log-Likelihood:                -14517.
# No. Observations:                1470   AIC:                         2.904e+04
# Df Residuals:                    1468   BIC:                         2.905e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             6593.7618    185.720     35.504      0.000    6229.457    6958.066
# ...

# %%
X = data['HourlyRate']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.3663
# Date:                Sun, 03 May 2020   Prob (F-statistic):              0.545
# Time:                        23:16:42   Log-Likelihood:                -14517.
# No. Observations:                1470   AIC:                         2.904e+04
# Df Residuals:                    1468   BIC:                         2.905e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6743.9412    416.725     16.183      0.000    5926.502    7561.381
# ...

# %%
X = data['MonthlyRate']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.781
# Date:                Sun, 03 May 2020   Prob (F-statistic):              0.182
# Time:                        23:16:42   Log-Likelihood:                -14516.
# No. Observations:                1470   AIC:                         2.904e+04
# Df Residuals:                    1468   BIC:                         2.905e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        6173.3439    275.773     22.386      0.000    5632.394    6714.294
# ...

# %%
X = data['NumCompaniesWorked']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     33.57
# Date:                Sun, 03 May 2020   Prob (F-statistic):           8.41e-09
# Time:                        23:16:43   Log-Likelihood:                -14501.
# No. Observations:                1470   AIC:                         2.901e+04
# Df Residuals:                    1468   BIC:                         2.902e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               5744.0182    178.631     32.156      0.000    5393.618    6094.418
# ...

# %%
X = data['PercentSalaryHike']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.092
# Date:                Sun, 03 May 2020   Prob (F-statistic):              0.296
# Time:                        23:16:43   Log-Likelihood:                -14517.
# No. Observations:                1470   AIC:                         2.904e+04
# Df Residuals:                    1468   BIC:                         2.905e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              7036.4345    525.007     13.403      0.000    6006.591    8066.278
# ...

# %%
X = data['TotalWorkingYears']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.597
# Model:                            OLS   Adj. R-squared:                  0.597
# Method:                 Least Squares   F-statistic:                     2178.
# Date:                Sun, 03 May 2020   Prob (F-statistic):          2.73e-292
# Time:                        23:16:44   Log-Likelihood:                -13848.
# No. Observations:                1470   AIC:                         2.770e+04
# Df Residuals:                    1468   BIC:                         2.771e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              1227.9353    137.299      8.944      0.000     958.612    1497.259
# ...

# %%
X = data['TrainingTimesLastYear']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.6939
# Date:                Sun, 03 May 2020   Prob (F-statistic):              0.405
# Time:                        23:16:45   Log-Likelihood:                -14517.
# No. Observations:                1470   AIC:                         2.904e+04
# Df Residuals:                    1468   BIC:                         2.905e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  6725.1221    293.645     22.902      0.000    6149.114    7301.130
# ...

# %%
X = data['StandardHours']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       inf
# Date:                Sun, 03 May 2020   Prob (F-statistic):                nan
# Time:                        23:16:45   Log-Likelihood:                -14517.
# No. Observations:                1470   AIC:                         2.904e+04
# Df Residuals:                    1469   BIC:                         2.904e+04
# Df Model:                           0
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# StandardHours    81.2866      1.535     52.958      0.000      78.276      84.297
# ...

# %%
X = data['YearsAtCompany']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.264
# Model:                            OLS   Adj. R-squared:                  0.264
# Method:                 Least Squares   F-statistic:                     527.9
# Date:                Sun, 03 May 2020   Prob (F-statistic):          4.82e-100
# Time:                        23:16:47   Log-Likelihood:                -14291.
# No. Observations:                1470   AIC:                         2.859e+04
# Df Residuals:                    1468   BIC:                         2.860e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           3733.2731    160.091     23.320      0.000    3419.242    4047.305
# ...

# %%
X = data['YearsInCurrentRole']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.132
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     224.0
# Date:                Sun, 03 May 2020   Prob (F-statistic):           3.13e-47
# Time:                        23:16:48   Log-Likelihood:                -14413.
# No. Observations:                1470   AIC:                         2.883e+04
# Df Residuals:                    1468   BIC:                         2.884e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               4503.5528    175.901     25.603      0.000    4158.509    4848.596
# ...

# %%
X = data['YearsSinceLastPromotion']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.118
# Method:                 Least Squares   F-statistic:                     198.3
# Date:                Sun, 03 May 2020   Prob (F-statistic):           2.44e-42
# Time:                        23:16:49   Log-Likelihood:                -14424.
# No. Observations:                1470   AIC:                         2.885e+04
# Df Residuals:                    1468   BIC:                         2.886e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    5400.2790    139.370     38.748      0.000    5126.894    5673.664
# ...

# %%
X = data['YearsWithCurrManager']
y = data['MonthlyIncome']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.118
# Model:                            OLS   Adj. R-squared:                  0.118
# Method:                 Least Squares   F-statistic:                     197.1
# Date:                Sun, 03 May 2020   Prob (F-statistic):           4.10e-42
# Time:                        23:16:49   Log-Likelihood:                -14425.
# No. Observations:                1470   AIC:                         2.885e+04
# Df Residuals:                    1468   BIC:                         2.886e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 4631.0598    176.284     26.270      0.000    4285.264    4976.856
# ...

# %% [markdown]
# # C-->Q
# # t test for 2 independent variables
# # f test for more than 2 independent variables

# %%
from scipy.stats import ttest_ind

# %%
# t-test for two inependent sample (C->Q)
# 2-sample t-test 
gender_M = data[data['Gender']=='Male']['MonthlyIncome']
gender_F = data[data['Gender']=='Female']['MonthlyIncome']
ttest_ind(gender_M,gender_F, axis = 0, nan_policy = 'omit')
# Out:
# Ttest_indResult(statistic=-1.2212617308870655, pvalue=0.22218303455087898)

# %%
# More thab Two independent samples (C->Q)
# One way F test - Anova

temp = data[['MonthlyIncome','BusinessTravel']]
grps = pd.unique(temp['BusinessTravel'])
d_data = {grp:data['MonthlyIncome'][data.BusinessTravel == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data['Travel_Rarely'],d_data['Travel_Frequently'],d_data['Non-Travel'])
# Out:
# F_onewayResult(statistic=1.114947529409662, pvalue=0.3282102052878377)

# %%
temp = data[['MonthlyIncome','Department']]
grps = pd.unique(temp['Department'])
d_data = {grp:data['MonthlyIncome'][data.Department == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data['Research & Development'],d_data['Sales'],d_data['Human Resources'])
# Out:
# F_onewayResult(statistic=3.2017829294201707, pvalue=0.04097409724987449)

# %%
data['Education'].value_counts()
temp = data[['MonthlyIncome','Education']]
grps = pd.unique(temp['Education'])
d_data = {grp:data['MonthlyIncome'][data.Education == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data[1],d_data[2],d_data[3],d_data[4],d_data[5])
# Out:
# F_onewayResult(statistic=3.8929774134094077, pvalue=0.003768508926919263)

# %%
data['EducationField'].value_counts()

temp = data[['MonthlyIncome','EducationField']]
grps = pd.unique(temp['EducationField'])
d_data = {grp:data['MonthlyIncome'][data.EducationField == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data['Life Sciences'],d_data['Medical'],d_data['Marketing'],d_data['Technical Degree'],
               d_data['Other'],d_data['Human Resources'])
# Out:
# F_onewayResult(statistic=1.9721849268901284, pvalue=0.07996005504292002)

# %%
data['EnvironmentSatisfaction'].value_counts()
temp = data[['MonthlyIncome','EnvironmentSatisfaction']]
grps = pd.unique(temp['EnvironmentSatisfaction'])
d_data = {grp:data['MonthlyIncome'][data.EnvironmentSatisfaction == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data[1],d_data[2],d_data[3],d_data[4])
# Out:
# F_onewayResult(statistic=0.4100354895826735, pvalue=0.7458160617247607)

# %%
data['JobInvolvement'].value_counts()
temp = data[['MonthlyIncome','JobInvolvement']]
grps = pd.unique(temp['JobInvolvement'])
d_data = {grp:data['MonthlyIncome'][data.JobInvolvement == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data[1],d_data[2],d_data[3],d_data[4])
# Out:
# F_onewayResult(statistic=0.33027980535988144, pvalue=0.8034678043580155)

# %%
data['JobLevel'].value_counts()
temp = data[['MonthlyIncome','JobLevel']]
grps = pd.unique(temp['JobLevel'])
d_data = {grp:data['MonthlyIncome'][data.JobLevel == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data[1],d_data[2],d_data[3],d_data[4],d_data[5])
# Out:
# F_onewayResult(statistic=4530.221139865191, pvalue=0.0)

# %%
data['JobRole'].value_counts()

temp = data[['MonthlyIncome','JobRole']]
grps = pd.unique(temp['JobRole'])
d_data = {grp:data['MonthlyIncome'][data.JobRole == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data['Sales Executive'],d_data['Research Scientist'],d_data['Laboratory Technician'],d_data['Manufacturing Director'],d_data['Healthcare Representative'],d_data['Manager'],d_data['Sales Representative'],
               d_data['Research Director'],d_data['Human Resources'])
# Out:
# F_onewayResult(statistic=810.2140539160126, pvalue=0.0)

# %%
data['JobSatisfaction'].value_counts()
temp = data[['MonthlyIncome','JobSatisfaction']]
grps = pd.unique(temp['JobSatisfaction'])
d_data = {grp:data['MonthlyIncome'][data.JobSatisfaction == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data[1],d_data[2],d_data[3],d_data[4])
# Out:
# F_onewayResult(statistic=0.027038829545482108, pvalue=0.9940001654548951)

# %%
data['MaritalStatus'].value_counts()
temp = data[['MonthlyIncome','MaritalStatus']]
grps = pd.unique(temp['MaritalStatus'])
d_data = {grp:data['MonthlyIncome'][data.MaritalStatus == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data['Married'],d_data['Single'],d_data['Divorced'])
# Out:
# F_onewayResult(statistic=5.904753323759054, pvalue=0.002791675956684596)

# %%
data['PerformanceRating'].value_counts()
temp = data[['MonthlyIncome','PerformanceRating']]
grps = pd.unique(temp['PerformanceRating'])
d_data = {grp:data['MonthlyIncome'][data.PerformanceRating == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data[3],d_data[4])
# Out:
# F_onewayResult(statistic=0.4303956762361691, pvalue=0.5118976688640235)

# %%
data['PerformanceRating'].value_counts()
three= data[data['PerformanceRating']==3]['MonthlyIncome']
four = data[data['PerformanceRating']==4]['MonthlyIncome']
ttest_ind(three,four, axis = 0, nan_policy = 'omit')
# Out:
# Ttest_indResult(statistic=0.6560454833593249, pvalue=0.5118976688639708)

# %%
data['OverTime'].value_counts()
No = data[data['OverTime']=='No']['MonthlyIncome']
Yes = data[data['OverTime']=='Yes']['MonthlyIncome']
ttest_ind(No,Yes, axis = 0, nan_policy = 'omit')
# Out:
# Ttest_indResult(statistic=-0.2333121788024749, pvalue=0.8155515298402164)

# %%
data['RelationshipSatisfaction'].value_counts()
temp = data[['MonthlyIncome','RelationshipSatisfaction']]
grps = pd.unique(temp['RelationshipSatisfaction'])
d_data = {grp:data['MonthlyIncome'][data.RelationshipSatisfaction == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data[1],d_data[2],d_data[3],d_data[4])
# Out:
# F_onewayResult(statistic=0.5529692450283559, pvalue=0.6461913878897791)

# %%
data['StockOptionLevel'].value_counts()
temp = data[['MonthlyIncome','StockOptionLevel']]
grps = pd.unique(temp['StockOptionLevel'])
d_data = {grp:data['MonthlyIncome'][data.StockOptionLevel == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data[0],d_data[1],d_data[2],d_data[3])
# Out:
# F_onewayResult(statistic=4.203291003303185, pvalue=0.005690921933562118)

# %%
data['WorkLifeBalance'].value_counts()
temp = data[['MonthlyIncome','WorkLifeBalance']]
grps = pd.unique(temp['WorkLifeBalance'])
d_data = {grp:data['MonthlyIncome'][data.WorkLifeBalance == grp] for grp in grps}
#print(d_data)
stats.f_oneway(d_data[1],d_data[2],d_data[3],d_data[4])
# Out:
# F_onewayResult(statistic=0.6123542986718447, pvalue=0.6070161552855458)

# %%
data['Attrition'].value_counts()
No = data[data['OverTime']==0]['MonthlyIncome']
Yes= data[data['OverTime']==1]['MonthlyIncome']
ttest_ind(No,Yes, axis = 0, nan_policy = 'omit')
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %% [markdown]
# # List of features selected by Test of Hypothesis

# %% [markdown]
# Age
# Department
# Education
# EducationField
# JobLevel
# JobRole
# MaritalStatus
# MonthlyIncome
# NumCompaniesWorked
# StockOptionLevel
# TotalWorkingYears
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager

# %%
toh_data = data.drop(['DailyRate','DistanceFromHome','HourlyRate','MonthlyRate',
                       'PercentSalaryHike','StandardHours',
                      'TrainingTimesLastYear','EmployeeCount','EmployeeNumber','Over18','Gender','BusinessTravel',
                      'EnvironmentSatisfaction','JobInvolvement','WorkLifeBalance',
                       'JobSatisfaction','PerformanceRating','OverTime','RelationshipSatisfaction',
                       'Attrition'],axis=1)

# %%
toh_data.columns
# Out:
# Index(['Age', 'Department', 'Education', 'EducationField', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'StockOptionLevel', 'TotalWorkingYears', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
toh_data.dtypes
# Out:
# Age                           int64
# Department                 category
# Education                  category
# EducationField             category
# JobLevel                   category
# JobRole                    category
# MaritalStatus              category
# MonthlyIncome                 int64
# NumCompaniesWorked            int64
# StockOptionLevel           category
# TotalWorkingYears             int64
# YearsAtCompany                int64
# YearsInCurrentRole            int64
# YearsSinceLastPromotion       int64
# YearsWithCurrManager          int64
# dtype: object

# %%
toh_data.describe()
# Out:
#                Age  MonthlyIncome  NumCompaniesWorked  TotalWorkingYears  \
# count  1470.000000    1470.000000         1470.000000        1470.000000
# mean     36.923810    6502.931293            2.693197          11.279592
# std       9.135373    4707.956783            2.498009           7.780782
# min      18.000000    1009.000000            0.000000           0.000000
# 25%      30.000000    2911.000000            1.000000           6.000000
# 50%      36.000000    4919.000000            2.000000          10.000000
# 75%      43.000000    8379.000000            4.000000          15.000000
# max      60.000000   19999.000000            9.000000          40.000000
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count     1470.000000         1470.000000              1470.000000
# mean         7.008163            4.229252                 2.187755
# std          6.126525            3.623137                 3.222430
# ...

# %% [markdown]
# # check and remove outliers

# %%
plt.figure()
sns.boxplot(toh_data['Age'])

# %%
plt.figure()
sns.boxplot(toh_data['MonthlyIncome'])

# %%
rws_MI=toh_data.loc[toh_data.MonthlyIncome>toh_data.MonthlyIncome.quantile(.90)]
toh_data.drop(rws_MI.index,inplace=True)
#print(rws_MI.MonthlyIncome)
len(rws_MI.index)
# Out:
# 147

# %%
plt.figure()
sns.boxplot(toh_data['MonthlyIncome'])

# %%
plt.figure()
sns.boxplot(toh_data['TotalWorkingYears'])

# %%
rws_TWY=toh_data.loc[toh_data.TotalWorkingYears>toh_data.TotalWorkingYears.quantile(.95)]
toh_data.drop(rws_TWY.index,inplace=True)
#print(rws_TWY.TotalWorkingYears)
len(rws_TWY.index)
# Out:
# 67

# %%
plt.figure()
sns.boxplot(toh_data['TotalWorkingYears'])

# %%
plt.figure()
sns.boxplot(toh_data['YearsAtCompany'])

# %%
plt.figure()
sns.boxplot(toh_data['YearsInCurrentRole'])

# %%
# remove outliers

rws_yic=toh_data.loc[toh_data.YearsInCurrentRole>toh_data.YearsInCurrentRole.quantile(.99)]
toh_data.drop(rws_yic.index,inplace=True)
#print(rws_TWY.TotalWorkingYears)
len(rws_yic.index)
# Out:
# 11

# %%
sns.boxplot(toh_data['YearsInCurrentRole'])

# %%
plt.figure()
sns.boxplot(toh_data['YearsWithCurrManager'])

# %%
# remove outliers

rws_ycm=toh_data.loc[toh_data.YearsWithCurrManager>toh_data.YearsWithCurrManager.quantile(.99)]
toh_data.drop(rws_ycm.index,inplace=True)
#print(rws_TWY.TotalWorkingYears)
len(rws_ycm.index)
# Out:
# 13

# %%
plt.figure()
sns.boxplot(toh_data['YearsWithCurrManager'])

# %%
plt.figure()
sns.boxplot(toh_data['YearsSinceLastPromotion'])

# %%
rws_ylp=toh_data.loc[toh_data.YearsSinceLastPromotion>toh_data.YearsSinceLastPromotion.quantile(.96)]
toh_data.drop(rws_ylp.index,inplace=True)
#print(rws_TWY.TotalWorkingYears)
len(rws_ylp.index)
# Out:
# 41

# %%
plt.figure()
sns.boxplot(toh_data['YearsSinceLastPromotion'])

# %%
toh_data.describe()
# Out:
#                Age  MonthlyIncome  NumCompaniesWorked  TotalWorkingYears  \
# count  1191.000000    1191.000000         1191.000000        1191.000000
# mean     34.935348    4854.402183            2.601175           8.474391
# std       8.298325    2616.841656            2.478743           4.661028
# min      18.000000    1009.000000            0.000000           0.000000
# 25%      29.000000    2717.000000            1.000000           5.000000
# 50%      34.000000    4319.000000            1.000000           8.000000
# 75%      40.000000    6154.000000            4.000000          10.000000
# max      60.000000   13757.000000            9.000000          20.000000
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count     1191.000000         1191.000000              1191.000000
# mean         5.334173            3.523090                 1.399664
# std          3.701351            2.983303                 1.959197
# ...

# %%
toh_data.dtypes
# Out:
# Age                           int64
# Department                 category
# Education                  category
# EducationField             category
# JobLevel                   category
# JobRole                    category
# MaritalStatus              category
# MonthlyIncome                 int64
# NumCompaniesWorked            int64
# StockOptionLevel           category
# TotalWorkingYears             int64
# YearsAtCompany                int64
# YearsInCurrentRole            int64
# YearsSinceLastPromotion       int64
# YearsWithCurrManager          int64
# dtype: object

# %%
TOH_DATA = pd.get_dummies(toh_data ,columns = ['Department','EducationField','JobRole','MaritalStatus']
                     ,drop_first=True)

# %%
TOH_DATA.columns
# Out:
# Index(['Age', 'Education', 'JobLevel', 'MonthlyIncome', 'NumCompaniesWorked',
#        'StockOptionLevel', 'TotalWorkingYears', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'Department_Research & Development', 'Department_Sales',
#        'EducationField_Life Sciences', 'EducationField_Marketing',
#        'EducationField_Medical', 'EducationField_Other',
#        'EducationField_Technical Degree', 'JobRole_Human Resources',
#        'JobRole_Laboratory Technician', 'JobRole_Manager',
#        'JobRole_Manufacturing Director', 'JobRole_Research Director',
#        'JobRole_Research Scientist', 'JobRole_Sales Executive',
#        'JobRole_Sales Representative', 'MaritalStatus_Married',
#        'MaritalStatus_Single'],
#       dtype='object')

# %%
len(TOH_DATA.index)
# Out:
# 1191

# %%
path_toh= "C:\\Users\\User\\Desktop\\DATA SCIENCE\\Abhinav R\\datasets\\MonthlyIncome_EDA_TOH.csv"
TOH_DATA.to_csv(path_toh)

# %% [markdown]
# # By performing Exploratory Data Analysis and Test of hypothesis, the final required data is stored in a file 'MonthlyIncome_EDA_TOH.csv'.
